# %%
import itertools
from itertools import permutations

import pandas as pd
import numpy as np
from matplotlib import pyplot as plt

# %matplotlib inline

# %% [markdown]
# ## Input data
#
# * Tox21 compounds with cluster assignment
# * Compound to target annotations from pharos and drug hub
# * Target enrichment results for each cluster

# %%
tox21_data = pd.read_csv("data_w_identifiers.csv")
target_data = pd.read_csv("pharos_and_drughub.csv")
enrichment_results = pd.read_csv("enrichment_analysis_results.csv")

# %%
tox21_data.head()
# Out:
#    cluster          cas         chembl  pubchem_cid  \
# 0        1  129299-90-7  CHEMBL3185034     180494.0
# 1        1  NOCAS_48522            NaN   60196348.0
# 2        1   33414-30-1  CHEMBL1620387     969494.0
# 3        1      84-02-6  CHEMBL1314751    5281032.0
# 4        1  289716-94-5   CHEMBL488060    9861124.0
#
#                                               smiles  \
# 0           Cl.Cc4ncnc4C[C@H]3CCc2c(C)c1ccccc1n2C3=O
# 1  FC(F)(F)C(=O)O.CCN(CC)C(=O)c1cc(c(cc1N(CC)CCN(...
# 2   CN1CCN(CC1)CCC(=O)N2c4ccccc4Sc3ccc(cc23)C(F)(F)F
# 3  O=C(O)/C=C\C(=O)O.O=C(O)/C=C\C(=O)O.CN1CCN(CC1...
# 4                      Clc2ccc(Oc1ccc(F)cc1CNC)cc2Cl
#
#                       inchikey                     sample_name  \
# 0                          NaN        Fabesetron hydrochloride
# 1  XDSUEKSKAPHPTN-UHFFFAOYSA-N  HMR1171 trifluoroacetate (1:1)
# 2  DOUQJBPSTIKRPH-UHFFFAOYSA-N                    Ftormetazine
# 3  DSKIOWHQLUWFLG-SPIKMXEPSA-N      Prochlorperazine dimaleate
# 4  FQEBOQLYHASAOY-UHFFFAOYSA-N                       CP-607366
#
#                mechanism_of_action
# 0                              NaN
# 1                              NaN
# 2                              NaN
# 3  Dopamine D2 receptor antagonist
# 4                              NaN

# %%
target_data.head()
# Out:
#         cas  cluster                     inchikey target_gene
# 0  303-49-1        1  GDLIGKIOYRNHDA-UHFFFAOYSA-N       GSTP1
# 1  303-49-1        1  GDLIGKIOYRNHDA-UHFFFAOYSA-N       HTR2A
# 2  303-49-1        1  GDLIGKIOYRNHDA-UHFFFAOYSA-N       HTR2B
# 3  303-49-1        1  GDLIGKIOYRNHDA-UHFFFAOYSA-N       HTR2C
# 4  303-49-1        1  GDLIGKIOYRNHDA-UHFFFAOYSA-N      SLC6A2

# %%
enrichment_results.head()
# Out:
#    cluster target_gene  TruePos  FalsePos  FalseNeg  TrueNeg  \
# 0        1       ABCB1        1        11        11     1078
# 1        1        ACHE        1        27        11     1062
# 2        1      ADRA1A        1        35        11     1054
# 3        1      ADRA1B        1        26        11     1063
# 4        1      ADRA1D        3        32         9     1057
#
#    TotalCmpdsTested  OddsRatio     p_val
# 0              1101   8.909091  0.123811
# 1              1101   3.575758  0.267066
# 2              1101   2.737662  0.330330
# 3              1101   3.716783  0.258785
# 4              1101  11.010417  0.005324

# %% [markdown]
# ## Filter and merge
#
# * Filter enrichments based on p-value (TODO: use better cutoff)
# * Merge target and cluster data

# %%
target_data = target_data.merge(
    tox21_data[['inchikey','chembl','pubchem_cid','sample_name']].drop_duplicates(),
    on='inchikey',how='inner')

# %%
target_data
# Out:
#            cas  cluster                     inchikey target_gene  \
# 0     303-49-1        1  GDLIGKIOYRNHDA-UHFFFAOYSA-N       GSTP1
# 1     303-49-1        1  GDLIGKIOYRNHDA-UHFFFAOYSA-N       HTR2A
# 2     303-49-1        1  GDLIGKIOYRNHDA-UHFFFAOYSA-N       HTR2B
# 3     303-49-1        1  GDLIGKIOYRNHDA-UHFFFAOYSA-N       HTR2C
# 4     303-49-1        1  GDLIGKIOYRNHDA-UHFFFAOYSA-N      SLC6A2
# ...        ...      ...                          ...         ...
# 5385  521-74-4      144  ZDASUJMDVPTNTF-UHFFFAOYSA-N    HSP90AA1
# 5386  140-89-6      144  JCBJVAJGLKENNC-UHFFFAOYSA-M         CA1
# 5387  140-89-6      144  JCBJVAJGLKENNC-UHFFFAOYSA-M         CA2
# 5388  140-89-6      144  JCBJVAJGLKENNC-UHFFFAOYSA-M        CA12
# 5389  140-89-6      144  JCBJVAJGLKENNC-UHFFFAOYSA-M         CA9
#
#              chembl  pubchem_cid                 sample_name
# 0         CHEMBL415       2801.0  Clomipramine hydrochloride
# 1         CHEMBL415       2801.0  Clomipramine hydrochloride
# 2         CHEMBL415       2801.0  Clomipramine hydrochloride
# 3         CHEMBL415       2801.0  Clomipramine hydrochloride
# 4         CHEMBL415       2801.0  Clomipramine hydrochloride
# ...             ...          ...                         ...
# 5385   CHEMBL223448       2453.0              Broxyquinoline
# 5386  CHEMBL2380738    2735045.0    Potassium ethyl xanthate
# 5387  CHEMBL2380738    2735045.0    Potassium ethyl xanthate
# 5388  CHEMBL2380738    2735045.0    Potassium ethyl xanthate
# 5389  CHEMBL2380738    2735045.0    Potassium ethyl xanthate
#
# [5390 rows x 7 columns]

# %%
cutoff=0.05/target_data.shape[0]
significant_enrichments = enrichment_results[enrichment_results['p_val']<cutoff]

# %%
significant_enrichments
# Out:
#       cluster target_gene  TruePos  FalsePos  FalseNeg  TrueNeg  \
# 12          1       CALM1        4         4         8     1085
# 20          1      CYP2D6        6        37         6     1052
# 34          1       HTR2C        6        36         6     1053
# 36          1        HTR6        5        22         7     1067
# 39          1       KCNH2        7        56         5     1033
# 140         4       NR3C1       31        19         1     1050
# 143         4     PLA2G1B        4         2        28     1067
# 144         4    SERPINA6        7         9        25     1060
# 442        16         PGR        5        17         1     1078
# 691        24       PTGS1       10        39         8     1044
# 692        24       PTGS2       11        43         7     1040
# 777        27      ATP1A1        3         3         4     1091
# 778        27      ATP1A2        3         0         4     1094
# 779        27      ATP1A3        3         0         4     1094
# 780        27      ATP1A4        3         0         4     1094
# 781        27      ATP1B1        3         0         4     1094
# 782        27      ATP1B2        3         0         4     1094
# 783        27      ATP1B3        3         0         4     1094
# 787        27       FXYD2        3         0         4     1094
# 842        29       POLA1        4         1         8     1088
# 845        29        POLE        3         0         9     1089
# 849        29        RRM1        3         1         9     1088
# 850        29        RRM2        3         1         9     1088
# 870        29        TYMS        5         4         7     1085
# 916        31        DRD3       10        38         8     1045
# 917        31        DRD4        6        25        12     1058
# 927        31       HTR2A        9        52         9     1031
# 967        35      AKR1C3        4         4        15     1078
# 1035       35       PTGS1        7        42        12     1040
# 1452       62     CYP17A1        4         3         1     1093
# 1507       64       ADRB1        5        13         9     1074
# 1508       64       ADRB2        6         9         8     1078
# 1756       78       ABCC8        5         7        11     1078
# 1771       78      KCNJ10        4         3        12     1082
# 1772       78      KCNJ11        5        11        11     1074
# 2280       94        ESR1        5        34         2     1060
# 2281       94        ESR2        6        20         1     1074
# 2854      104          AR       11        23        16     1051
# 2859      104        ESR1       16        23        11     1051
# 2860      104        ESR2        8        18        19     1056
# 2898      104        SHBG       14        16        13     1058
# 2934      105        DPP4        4         2         7     1088
# 2937      105       ESRRA        3         2         8     1088
# 2938      105       ESRRB        3         2         8     1088
# 3462      120       HMGCR        4         1         3     1093
# 3737      131       HTR2A        7        54         9     1031
# 3771      132       CHRM1        6        37         6     1052
# 3773      132       CHRM3        6        31         6     1058
# 3777      132        DRD2        6        49         6     1040
# 3788      132       HTR2A        7        54         5     1035
# 3790      132       HTR2C        6        36         6     1053
# 3808      133        ACHE        4        24         0     1073
#
#       TotalCmpdsTested    OddsRatio         p_val
# 12                1101   135.625000  5.560000e-07
# 20                1101    28.432432  1.930000e-06
# 34                1101    29.250000  1.670000e-06
# 36                1101    34.642857  4.250000e-06
# 39                1101    25.825000  9.130000e-07
# 140               1101  1713.157895  6.100000e-46
# 143               1101    76.214286  8.500000e-06
# 144               1101    32.977778  8.410000e-08
# 442               1101   317.058824  1.170000e-08
# 691               1101    33.461538  3.990000e-10
# 692               1101    38.006645  3.430000e-11
# 777               1101   272.750000  3.130000e-06
# 778               1101          inf  1.580000e-07
# 779               1101          inf  1.580000e-07
# 780               1101          inf  1.580000e-07
# 781               1101          inf  1.580000e-07
# 782               1101          inf  1.580000e-07
# 783               1101          inf  1.580000e-07
# 787               1101          inf  1.580000e-07
# 842               1101   544.000000  4.040000e-08
# 845               1101          inf  9.920000e-07
# 849               1101   362.666667  3.940000e-06
# 850               1101   362.666667  3.940000e-06
# 870               1101   193.750000  7.310000e-09
# 916               1101    34.375000  3.190000e-10
# 917               1101    21.160000  4.420000e-06
# 927               1101    19.826923  8.960000e-08
# 967               1101    71.866667  4.260000e-06
# 1035              1101    14.444444  7.520000e-06
# 1452              1101  1457.333333  2.870000e-09
# 1507              1101    45.897436  1.170000e-06
# 1508              1101    89.833333  5.820000e-09
# 1756              1101    70.000000  2.440000e-07
# 1771              1101   120.222222  1.020000e-06
# 1772              1101    44.380165  1.300000e-06
# 2280              1101    77.941176  8.590000e-07
# 2281              1101   322.200000  6.500000e-10
# 2854              1101    31.415761  3.970000e-11
# 2859              1101    66.466403  1.970000e-18
# 2860              1101    24.701754  5.010000e-08
# 2898              1101    71.211538  6.000000e-17
# 2934              1101   310.857143  8.050000e-08
# 2937              1101   204.000000  7.360000e-06
# 2938              1101   204.000000  7.360000e-06
# 3462              1101  1457.333333  2.870000e-09
# 3737              1101    14.849794  8.790000e-06
# 3771              1101    28.432432  1.930000e-06
# 3773              1101    34.129032  7.600000e-07
# 3777              1101    21.224490  8.680000e-06
# 3788              1101    26.833333  7.260000e-07
# 3790              1101    29.250000  1.670000e-06
# 3808              1101          inf  3.360000e-07

# %% [markdown]
# # Find novel compound - target candidates
#
# * A novel compound-target pair candidate is defined as:
#     * The compound is in the cluster
#     * The target is in enriched in the cluster
#     * The compound is not known have activity against the target
# * I will then tier the candidate pairs in the following way:
#     * Tier 1: If the compound is known to have activity against a different enriched target
#         * Justification: the enriched targets may be related and so activity against one may suggest activity against another
#     * Tier 2: If the compound is known to have activity against ANY target
#         * Justification: if a compound has a target annotation then it has been studied in a bioassay and at least has some biological activity, thus is more likely to have activity against other targets too
#     * Tier 3: Pairs with compounds having no annotation
# * Within each tier, the candidate pairs could be sorted by the number of compounds with known activity against the target -- but this makes sense as a global analysis not within tox21 compounds only.

# %%
compound_targets = {}
for i, row in target_data.iterrows():
    if (row['cas'],row['inchikey']) in compound_targets:
        compound_targets[(row['cas'],row['inchikey'])].append(row['target_gene'])
    else:
        compound_targets[(row['cas'],row['inchikey'])] = [row['target_gene']]

# %%
focal_cluster_enrichments
# Out:
#      cluster target_gene  TruePos  FalsePos  FalseNeg  TrueNeg  \
# 916       31        DRD3       10        38         8     1045
# 917       31        DRD4        6        25        12     1058
# 927       31       HTR2A        9        52         9     1031
#
#      TotalCmpdsTested  OddsRatio         p_val
# 916              1101  34.375000  3.190000e-10
# 917              1101  21.160000  4.420000e-06
# 927              1101  19.826923  8.960000e-08

# %%
#not every cluster has significant targets
candidates = []
for focal_cluster in set(significant_enrichments['cluster']):
    focal_cluster_compounds = tox21_data[tox21_data['cluster']==focal_cluster]
    focal_cluster_enrichments = significant_enrichments[significant_enrichments['cluster']==focal_cluster]
    #focal_cluster_targets = target_data[target_data['cluster']==focal_cluster]
    
    
    #hashable_compound_keys = zip(focal_cluster_compounds['cas'],focal_cluster_compounds['inchikey'])
    
    for c, compound_row in focal_cluster_compounds.iterrows():
        for t, target_row in focal_cluster_enrichments.iterrows():
            #confirm this compound - target pair is not an existing annotations
            candidate_row = {**dict(compound_row),**dict(target_row)}
            compound_annot = compound_targets.get((compound_row['cas'],compound_row['inchikey']))
            if compound_annot is not None:
                
                if target_row['target_gene'] in compound_annot:
                    #compound has known activity against this target
                    pass
                elif len(set(focal_cluster_enrichments['target_gene']).intersection(set(compound_annot)))>0:
                    #compound has activity against a different enriched target 
                    candidate_row['tier'] = 'Tier 1'
                    candidates.append(candidate_row)
                else:
                    #compound has activity against another target (not enriched in this cluster)
                    candidate_row['tier'] = 'Tier 2'
                    candidates.append(candidate_row)
                
            else:
                candidate_row['tier'] = 'Tier 3'
                candidates.append(candidate_row)      
                
    
    
compound_target_candidates = pd.DataFrame(candidates)

# %%
compound_target_candidates
# Out:
#       cluster          cas         chembl  pubchem_cid  \
# 0          64   54239-37-1  CHEMBL1374751       2755.0
# 1          64   72332-33-3  CHEMBL1478530     688561.0
# 2          64   94749-08-3  CHEMBL1082607      56801.0
# 3          64   94749-08-3  CHEMBL1082607      56801.0
# 4          64  101975-10-4   CHEMBL313842       5723.0
# ...       ...          ...            ...          ...
# 1840       31     537-12-2  CHEMBL1456312      10830.0
# 1841       31     537-12-2  CHEMBL1456312      10830.0
# 1842       31    5560-59-8  CHEMBL1408594      21718.0
# 1843       31    5560-59-8  CHEMBL1408594      21718.0
# 1844       31    5560-59-8  CHEMBL1408594      21718.0
#
#                                                  smiles  \
# 0                             N#Cc1cc(ccc1N)C(O)CNC(C)C
# 1        CC(C)N[C@@H](CC)[C@H](O)c2ccc(O)c1NC(=O)C=Cc12
# 2     OCc1cc(ccc1O)C(O)CNCCCCCCOCCCCc2ccccc2.O=C(O)c...
# 3     OCc1cc(ccc1O)C(O)CNCCCCCCOCCCCc2ccccc2.O=C(O)c...
# 4                     FC(F)Oc1ccc(cc1OC)C=2C=CC(=O)NN=2
# ...                                                 ...
# 1840     Cl.O=C(Nc1ccccc1)OCC(OC(=O)Nc2ccccc2)CN3CCCCC3
# 1841     Cl.O=C(Nc1ccccc1)OCC(OC(=O)Nc2ccccc2)CN3CCCCC3
# 1842  O=C(O)C(O)(CC(=O)O)CC(=O)O.CCN(CCCc1ccccc1)CCC...
# 1843  O=C(O)C(O)(CC(=O)O)CC(=O)O.CCN(CCCc1ccccc1)CCC...
# 1844  O=C(O)C(O)(CC(=O)O)CC(=O)O.CCN(CCCc1ccccc1)CCC...
#
#                          inchikey              sample_name  \
# 0     BUXRLJCGHZZYNE-UHFFFAOYSA-N                Cimaterol
# 1     FKNXQNWAXFXVNW-BLLLJJGKSA-N               Procaterol
# 2     XTZNCVSCVHTPAI-UHFFFAOYSA-N     Salmeterol xinafoate
# 3     XTZNCVSCVHTPAI-UHFFFAOYSA-N     Salmeterol xinafoate
# 4     HJMQDJPMQIHLPB-UHFFFAOYSA-N              Zardaverine
# ...                           ...                      ...
# 1840  OWULVAZDMWJBLB-UHFFFAOYSA-N  Diperodon hydrochloride
# 1841  OWULVAZDMWJBLB-UHFFFAOYSA-N  Diperodon hydrochloride
# 1842  RYHCACJBKCOBTJ-UHFFFAOYSA-N         Alverine citrate
# 1843  RYHCACJBKCOBTJ-UHFFFAOYSA-N         Alverine citrate
# 1844  RYHCACJBKCOBTJ-UHFFFAOYSA-N         Alverine citrate
#
#                      mechanism_of_action target_gene  TruePos  FalsePos  \
# 0                                    NaN       ADRB2        6         9
# 1                                    NaN       ADRB1        5        13
# 2     Beta-2 adrenergic receptor agonist       ADRB1        5        13
# 3     Beta-2 adrenergic receptor agonist       ADRB2        6         9
# 4                                    NaN       ADRB1        5        13
# ...                                  ...         ...      ...       ...
# 1840                                 NaN        DRD4        6        25
# 1841                                 NaN       HTR2A        9        52
# 1842                                 NaN        DRD3       10        38
# 1843                                 NaN        DRD4        6        25
# 1844                                 NaN       HTR2A        9        52
#
#       FalseNeg  TrueNeg  TotalCmpdsTested  OddsRatio         p_val    tier
# 0            8     1078              1101  89.833333  5.820000e-09  Tier 1
# 1            9     1074              1101  45.897436  1.170000e-06  Tier 1
# 2            9     1074              1101  45.897436  1.170000e-06  Tier 3
# 3            8     1078              1101  89.833333  5.820000e-09  Tier 3
# 4            9     1074              1101  45.897436  1.170000e-06  Tier 2
# ...        ...      ...               ...        ...           ...     ...
# 1840        12     1058              1101  21.160000  4.420000e-06  Tier 3
# 1841         9     1031              1101  19.826923  8.960000e-08  Tier 3
# 1842         8     1045              1101  34.375000  3.190000e-10  Tier 2
# 1843        12     1058              1101  21.160000  4.420000e-06  Tier 2
# 1844         9     1031              1101  19.826923  8.960000e-08  Tier 2
#
# [1845 rows x 17 columns]

# %%
compound_target_candidates[compound_target_candidates['tier']=='Tier 1']
# Out:
#       cluster          cas         chembl  pubchem_cid  \
# 0          64   54239-37-1  CHEMBL1374751       2755.0
# 1          64   72332-33-3  CHEMBL1478530     688561.0
# 20         64   18559-94-9      CHEMBL714       2083.0
# 21         64   18559-94-9      CHEMBL714       2083.0
# 64          1  289716-94-5   CHEMBL488060    9861124.0
# ...       ...          ...            ...          ...
# 1816       31      52-53-9     CHEMBL6966       2520.0
# 1817       31      52-53-9     CHEMBL6966       2520.0
# 1821       31    5588-33-0     CHEMBL1088       4078.0
# 1834       31    1649-18-9   CHEMBL340211      15443.0
# 1835       31    1649-18-9   CHEMBL340211      15443.0
#
#                                                  smiles  \
# 0                             N#Cc1cc(ccc1N)C(O)CNC(C)C
# 1        CC(C)N[C@@H](CC)[C@H](O)c2ccc(O)c1NC(=O)C=Cc12
# 20                          OCc1cc(ccc1O)C(O)CNC(C)(C)C
# 21                          OCc1cc(ccc1O)C(O)CNC(C)(C)C
# 64                        Clc2ccc(Oc1ccc(F)cc1CNC)cc2Cl
# ...                                                 ...
# 1816  COc1cc(ccc1OC)C(C#N)(CCCN(C)CCc2ccc(OC)c(OC)c2...
# 1817  COc1cc(ccc1OC)C(C#N)(CCCN(C)CCc2ccc(OC)c(OC)c2...
# 1821            CS(=O)c2cc3N(CCC1CCCCN1C)c4ccccc4Sc3cc2
# 1834              Fc1ccc(cc1)C(=O)CCCN2CCN(CC2)c3ccccn3
# 1835              Fc1ccc(cc1)C(=O)CCCN2CCN(CC2)c3ccccn3
#
#                          inchikey         sample_name  \
# 0     BUXRLJCGHZZYNE-UHFFFAOYSA-N           Cimaterol
# 1     FKNXQNWAXFXVNW-BLLLJJGKSA-N          Procaterol
# 20    NDAUXUAQIAJITI-UHFFFAOYSA-N  Salbutamol sulfate
# 21    NDAUXUAQIAJITI-UHFFFAOYSA-N           Albuterol
# 64    FQEBOQLYHASAOY-UHFFFAOYSA-N           CP-607366
# ...                           ...                 ...
# 1816  SGTNSNPWRIOYBX-UHFFFAOYSA-N           Verapamil
# 1817  SGTNSNPWRIOYBX-UHFFFAOYSA-N           Verapamil
# 1821  SLVMESMUVMCQIY-UHFFFAOYSA-N        Mesoridazine
# 1834  XTKDAFGWCDAMPY-UHFFFAOYSA-N           Azaperone
# 1835  XTKDAFGWCDAMPY-UHFFFAOYSA-N           Azaperone
#
#                      mechanism_of_action target_gene  TruePos  FalsePos  \
# 0                                    NaN       ADRB2        6         9
# 1                                    NaN       ADRB1        5        13
# 20    Beta-2 adrenergic receptor agonist       ADRB1        5        13
# 21    Beta-2 adrenergic receptor agonist       ADRB1        5        13
# 64                                   NaN       CALM1        4         4
# ...                                  ...         ...      ...       ...
# 1816                                 NaN        DRD4        6        25
# 1817                                 NaN       HTR2A        9        52
# 1821                                 NaN        DRD4        6        25
# 1834                                 NaN        DRD4        6        25
# 1835                                 NaN       HTR2A        9        52
#
#       FalseNeg  TrueNeg  TotalCmpdsTested   OddsRatio         p_val    tier
# 0            8     1078              1101   89.833333  5.820000e-09  Tier 1
# 1            9     1074              1101   45.897436  1.170000e-06  Tier 1
# 20           9     1074              1101   45.897436  1.170000e-06  Tier 1
# 21           9     1074              1101   45.897436  1.170000e-06  Tier 1
# 64           8     1085              1101  135.625000  5.560000e-07  Tier 1
# ...        ...      ...               ...         ...           ...     ...
# 1816        12     1058              1101   21.160000  4.420000e-06  Tier 1
# 1817         9     1031              1101   19.826923  8.960000e-08  Tier 1
# 1821        12     1058              1101   21.160000  4.420000e-06  Tier 1
# 1834        12     1058              1101   21.160000  4.420000e-06  Tier 1
# 1835         9     1031              1101   19.826923  8.960000e-08  Tier 1
#
# [219 rows x 17 columns]

# %%
#Confirm no overlap between candidate set and target annotations
compound_target_candidates[['cas','inchikey','target_gene']].merge(target_data[['cas','inchikey','target_gene']],how='inner')
# Out:
# Empty DataFrame
# Columns: [cas, inchikey, target_gene]
# Index: []

# %%
compound_target_candidates.to_csv("tox21_cluster_compound_target_candidates.csv",index=False)
